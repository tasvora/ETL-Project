# %%
import pandas as pd

# %%
statename='Montana'

# %%
df = pd.read_excel(f"../Resources/Glassdoor/{statename}_glassdoor.xlsx")

# %%
df.dropna()
# Out:
#                            company  \
# 0                              GIG
# 1                         Deloitte
# 2                         Deloitte
# 3                           Socati
# 4                 State of Montana
# 5                  Billings Clinic
# 6                           EDULOG
# 7             Verint Systems, Inc.
# 8                              GSK
# 9                            Bayer
# 10                State of Montana
# 11         D.A. Davidson Companies
# 12           Livingston HealthCare
# 13            Camris International
# 14      Bozeman Deaconess Hospital
# 15  Advanced Technology Group (KS)
# 16        Cognizant US Corporation
# 17           University of Montana
# 18            Camris International
# 19      Bozeman Deaconess Hospital
# 20                       U.S. Bank
# 21        Cognizant US Corporation
# 22          The Great Falls Clinic
# 23          The Great Falls Clinic
# 24                       Kalispell
# 25                             GIG
# 26          The Great Falls Clinic
# 27            Camris International
# 28      Bozeman Deaconess Hospital
# 29   Montana State University, Inc
# 30    Providence Health & Services
#
#                                           description         location  \
# 0   \n-------------\n\n\nThe role\n\n\n\n---------...        Malta, MT
# 1   **Data Scientist Helena, MT**       Are you an...       Helena, MT
# 2   Data Scientist – Helena, MT\n\nAre you an expe...       Helena, MT
# 3   Job DescriptionBe a part of the evolution.\nWi...     Missoula, MT
# 4   TITLE: Data Analyst\n\nSTATUS: Permanent, Full...       Helena, MT
# 5   The Collaborative Science and Innovation (CSI)...     Billings, MT
# 6   DATA ANALYST\n\nWHY WORK WITH EDULOG?\n\nWork ...     Missoula, MT
# 7   \n*Data Engineer**\n\n\nLocation **US-Remote (...       Helena, MT
# 8   Site Name: USA - Montana - Hamilton\n\nPosted ...     Hamilton, MT
# 9    Bayer is a global enterprise with core compet...          Montana
# 10  Why should you keep reading and consider worki...       Helena, MT
# 11  Job Description:We are seeking to hire an expe...  Great Falls, MT
# 12  *Please apply at www.livingstonhealthcare.org\...   Livingston, MT
# 13  OverviewCAMRIS International is an internation...     Hamilton, MT
# 14  \n\n\nPOSITION DESCRIPTION\n\n\n\nPOSITION SUM...      Bozeman, MT
# 15  ATGer; noun; Rockstar of ATG – self-motivated,...     Missoula, MT
# 16  Data Engineer\n\nThis position may also be fil...     Missoula, MT
# 17  The Numerical Terradynamic Simulation Group (N...     Missoula, MT
# 18  OverviewCAMRIS International is an internation...     Hamilton, MT
# 19  \n\n\nPOSITION DESCRIPTION\n\n\n\nPOSITION SUM...      Bozeman, MT
# 20  U.S. Bank is seeking a Data Analyst in Informa...     Billings, MT
# 21  Data Engineer - Advanced Technology Group\n\nT...     Missoula, MT
# 22  Position Overview: Under the general supervisi...  Great Falls, MT
# 23  Position Overview:Under the general supervisio...  Great Falls, MT
# 24  CLS Position Summary: Works independently and ...    Whitefish, MT
# 25  The Role\n\nThe Big Data Engineer in Test (BDE...        Malta, MT
# 26  Position Overview:Under the general supervisio...  Great Falls, MT
# 27  OverviewCAMRIS International is an internation...     Hamilton, MT
# 28  \n\n\n\nPOSITION DESCRIPTION\n\n\n\nPOSITION S...      Bozeman, MT
# 29  Following an integrated, collaborative model, ...      Bozeman, MT
# 30  \n*Description:**\n*Providence is calling a Se...     Missoula, MT
#
#                          position  reviews Region
# 0                  data scientist        0   West
# 1                  data scientist        1   West
# 2                  data scientist        1   West
# 3                       analytics        0   West
# 4                    data analyst        5   West
# 5                    data analyst        4   West
# 6                    data analyst        0   West
# 7                   data engineer        0   West
# 8       senior research scientist        2   West
# 9        bioinformatics scientist        0   West
# 10                   data analyst        5   West
# 11                   data analyst        5   West
# 12                     bi analyst        1   West
# 13             research scientist        0   West
# 14                   data analyst        5   West
# 15                  data engineer        5   West
# 16                  data engineer        0   West
# 17             research scientist        5   West
# 18       bioinformatics scientist        0   West
# 19                 microbiologist        5   West
# 20                   data analyst        2   West
# 21                  data engineer        0   West
# 22  clinical laboratory scientist        5   West
# 23  clinical laboratory scientist        5   West
# 24  clinical laboratory scientist        0   West
# 25                  data engineer        0   West
# 26  clinical laboratory scientist        5   West
# 27      senior research scientist        0   West
# 28  clinical laboratory scientist        5   West
# 29  clinical laboratory scientist        5   West
# 30           senior data engineer        0   West

# %%
# filter only three most relevant position

df_Analyst = df[df['position'].str.contains('Data Analyst',case=False, na=False) ]
df_Scientist = df[df['position'].str.contains('Data Scientist',case=False, na=False) ]
df_Engineer = df[df['position'].str.contains('Data Engineer',case=False, na=False) ]

frames = [df_Analyst, df_Scientist, df_Scientist]
glassdoor_df = pd.concat(frames)

glassdoor_df.dropna()
# Out:
#                        company  \
# 4             State of Montana
# 5              Billings Clinic
# 6                       EDULOG
# 10            State of Montana
# 11     D.A. Davidson Companies
# 14  Bozeman Deaconess Hospital
# 20                   U.S. Bank
# 0                          GIG
# 1                     Deloitte
# 2                     Deloitte
# 0                          GIG
# 1                     Deloitte
# 2                     Deloitte
#
#                                           description         location  \
# 4   TITLE: Data Analyst\n\nSTATUS: Permanent, Full...       Helena, MT
# 5   The Collaborative Science and Innovation (CSI)...     Billings, MT
# 6   DATA ANALYST\n\nWHY WORK WITH EDULOG?\n\nWork ...     Missoula, MT
# 10  Why should you keep reading and consider worki...       Helena, MT
# 11  Job Description:We are seeking to hire an expe...  Great Falls, MT
# 14  \n\n\nPOSITION DESCRIPTION\n\n\n\nPOSITION SUM...      Bozeman, MT
# 20  U.S. Bank is seeking a Data Analyst in Informa...     Billings, MT
# 0   \n-------------\n\n\nThe role\n\n\n\n---------...        Malta, MT
# 1   **Data Scientist Helena, MT**       Are you an...       Helena, MT
# 2   Data Scientist – Helena, MT\n\nAre you an expe...       Helena, MT
# 0   \n-------------\n\n\nThe role\n\n\n\n---------...        Malta, MT
# 1   **Data Scientist Helena, MT**       Are you an...       Helena, MT
# 2   Data Scientist – Helena, MT\n\nAre you an expe...       Helena, MT
#
#           position  reviews Region
# 4     data analyst        5   West
# 5     data analyst        4   West
# 6     data analyst        0   West
# 10    data analyst        5   West
# 11    data analyst        5   West
# 14    data analyst        5   West
# 20    data analyst        2   West
# 0   data scientist        0   West
# 1   data scientist        1   West
# 2   data scientist        1   West
# 0   data scientist        0   West
# 1   data scientist        1   West
# 2   data scientist        1   West

# %%
# new data frame with split value columns 
location_df = glassdoor_df["location"].str.split(",", n = 1, expand = True) 

# add city
glassdoor_df["City"]= location_df[0] 
  
# add state
glassdoor_df["State"]= location_df[1] 
  
# Dropping old Name columns 
glassdoor_df.drop(columns =["location"], inplace = True) 

glassdoor_df.head()
# Out:
#                     company  \
# 4          State of Montana
# 5           Billings Clinic
# 6                    EDULOG
# 10         State of Montana
# 11  D.A. Davidson Companies
#
#                                           description      position  reviews  \
# 4   TITLE: Data Analyst\n\nSTATUS: Permanent, Full...  data analyst        5
# 5   The Collaborative Science and Innovation (CSI)...  data analyst        4
# 6   DATA ANALYST\n\nWHY WORK WITH EDULOG?\n\nWork ...  data analyst        0
# 10  Why should you keep reading and consider worki...  data analyst        5
# 11  Job Description:We are seeking to hire an expe...  data analyst        5
#
#    Region         City State
# 4    West       Helena    MT
# 5    West     Billings    MT
# 6    West     Missoula    MT
# 10   West       Helena    MT
# 11   West  Great Falls    MT

# %%
glassdoor_df.to_csv(f'../../Load/Resources/Glassdoor/{statename}_glassdoor.csv',sep='|',index=False)
