# %%
import pandas as pd

# %%
statename='Idaho'

# %%
df = pd.read_excel(f"../Resources/Glassdoor/{statename}_glassdoor.xlsx")

# %%
df.dropna()
# Out:
#                                  company  \
# 0                                 Amazon
# 1             Idaho Central Credit Union
# 3              Idaho National Laboratory
# 4                         Tea Collection
# 5                        Burst Biologics
# 6                      Micron Technology
# 7                                TSheets
# 8                Micron Technology, Inc.
# 9                                 Vacasa
# 10            Hewlett Packard Enterprise
# 11                     Applied Materials
# 12                                 P1FCU
# 13                   Denodo Technologies
# 14              St. Luke's Health System
# 15                                Micron
# 16            American Heart Association
# 17                                 Bayer
# 18                         iVinci Health
# 19                               Biomark
# 20                                  Emsi
# 21                      Bodybuilding.com
# 22                             Litehouse
# 23              St. Luke's Health System
# 24                                Vacasa
# 25                             U.S. Navy
# 26                        U.S. Air Force
# 27                          Agri-Service
# 28                               Safeway
# 29                 Parker Hannifin (USA)
# 30         Waterborne Environmental, Inc
# 32                  Verint Systems, Inc.
# 33                  Albertsons Companies
# 34               Micron Technology, Inc.
# 35               Micron Technology, Inc.
# 36            United Global Technologies
# 37                                Intuit
# 38                          ClickFunnels
# 39  Battelle Energy Alliance, LLC at INL
# 40              St. Luke's Health System
# 43                        Trinity Health
# 44                       Shell Petroleum
# 45                     Micron Technology
# 46               Micron Technology, Inc.
# 47                      Perkins Coie LLP
# 48               Micron Technology, Inc.
# 49                                Micron
# 50               Micron Technology, Inc.
# 51              St. Luke's Health System
# 52                                Micron
# 53                                Micron
# 54                     Micron Technology
# 55                                Micron
# 56               Micron Technology, Inc.
# 57                                Micron
# 58                                Micron
# 59               Micron Technology, Inc.
# 60                                Vacasa
# 61                                Micron
# 62                                Micron
#
#                                           description               location  \
# 0   Excited by using massive amounts of data to de...              Boise, ID
# 1   Do you enjoy working with other people and fin...           Chubbuck, ID
# 3   DescriptionJob Information\n\nJob Title: Data ...        Idaho Falls, ID
# 4   Expectations for All Employees:Supports the or...              Boise, ID
# 5   WHO WE ARE:\n\nBurst Biologics is a globally a...              Boise, ID
# 6   Req. ID: 139947\n\nMicron Technology’s vision ...              Boise, ID
# 7   OverviewAre you passionate about data? Do you ...              Eagle, ID
# 8   Req. ID: 143828\n\nData Scientist\n\nMicron Te...              Boise, ID
# 9   Why Vacasa\n\nWe started with just one home an...              Boise, ID
# 10  At Hewlett Packard Enterprise (HPE), we bring ...              Boise, ID
# 11  **Key Responsibilities**  Manage and facilitat...              Boise, ID
# 12  Job Description Role:\n\nCombines advanced mat...           Lewiston, ID
# 13  Company DescriptionDenodo is the leader in dat...              Boise, ID
# 14  \n*Overview**\n\n\nDo you like working on thin...              Boise, ID
# 15   Req. ID: 146013   Micron Technology’s vision ...              Boise, ID
# 16  \n*Overview**\n\n\nAre **you ready to join an ...              Boise, ID
# 17   Bayer is a global enterprise with core compet...       Soda Springs, ID
# 18  Summary of Position:\n\nThe Data Analyst I is ...              Boise, ID
# 19  Job Title:  Computer Scientist, Biomark\n\nDep...              Boise, ID
# 20  Position OverviewWe are looking for a highly m...             Moscow, ID
# 21  Bodybuilding.com is the world’s largest online...              Boise, ID
# 22  Basic Purpose and Scope:The R&D Food Scientist...          Sandpoint, ID
# 23  Overview\n\nFind your purpose and your best ca...              Boise, ID
# 24  Why Vacasa\n\nWe started with just one home an...              Boise, ID
# 25  You will serve as a Computer Scientist in the ...            Bayview, ID
# 26  Click on"Learn more about this agency" button ...  Mountain Home AFB, ID
# 27  Job DescriptionDo you have that ideal mix of s...          Blackfoot, ID
# 28  LLC CORPORATE OFFICE-9938A-BOISE-ID\n\nAlberts...              Boise, ID
# 29  Org Marketing Statement\n\nWith annual sales o...              Santa, ID
# 30  Data Analyst (Position Code VA/DA1119)\n\nData...           Leesburg, ID
# 32  \n*Data Engineer**\n\n\nLocation **US-Remote (...              Boise, ID
# 33  LLC CORPORATE OFFICE-9938A-BOISE-ID\n\nAlberts...              Boise, ID
# 34  Req. ID: 144161\n\nMicron Technology's vision ...              Boise, ID
# 35  Req Id: 145206\n\nMicron Technology's vision i...              Boise, ID
# 36  The Data Analytics Report Builder will assist ...        Idaho Falls, ID
# 37  OverviewAre you passionate about data? Do you ...              Eagle, ID
# 38  ClickFunnels is a company focused on changing ...              Boise, ID
# 39  \n \nThe Computational Frameworks department w...        Idaho Falls, ID
# 40  St. Luke’s Health System has an exciting oppor...              Boise, ID
# 43  At Saint Alphonsus Health System, we are looki...              Boise, ID
# 44  Data Engineer, Energy Platform - Houston, TX\n...            Houston, ID
# 45  Req. ID: 139422\n\nMicron Technology’s vision ...              Boise, ID
# 46  Req. ID: 145149\n\nEnjoy the meaningful and fa...              Boise, ID
# 47  Power Business Intelligence Analyst\n\nTechnol...              Boise, ID
# 48  Req. ID: 147941\n\nMicron Technology's vision ...              Boise, ID
# 49  Req. ID: 133968\n\nIT Data Engineer, Big Data\...              Boise, ID
# 50  Req. ID: 141987\n\nAs a Data Science Engineer ...              Boise, ID
# 51  \n*Overview**\n\n\nDo you like working on thin...              Boise, ID
# 52  Req. ID: 144161\n\nMicron Technology’s vision ...              Boise, ID
# 53  Req. ID: 144575\n\nMicron Technology’s vision ...              Boise, ID
# 54  Req. ID: 140108\n\nAre you looking for a uniqu...              Boise, ID
# 55  Req Id: 145206\n\nMicron Technology’s vision i...              Boise, ID
# 56  Req. ID: 144753\n\nMicron Technology's vision ...              Boise, ID
# 57  Req. ID: 133968\n\nIT Data Engineer, Big Data\...              Boise, ID
# 58  Req. ID: 147941\n\nMicron Technology’s vision ...              Boise, ID
# 59  Req. ID: 146523\n\nMicron Technology's vision ...              Boise, ID
# 60  Why Vacasa\n\nWe started with just one home an...              Boise, ID
# 61  Req. ID: 144753\n\nMicron Technology's vision ...              Boise, ID
# 62  Req. ID: 146523\n\nMicron Technology’s vision ...              Boise, ID
#
#                         position  reviews Region
# 0                 data scientist        0   West
# 1                     bi analyst        5   West
# 3                 data scientist        5   West
# 4                   data analyst        0   West
# 5             research scientist        4   West
# 6          data scientist intern        6   West
# 7   senior business data analyst        5   West
# 8                 data scientist        4   West
# 9                 data scientist        5   West
# 10           data manager intern        5   West
# 11                  data analyst        2   West
# 12                    bi analyst        1   West
# 13                 data engineer        0   West
# 14                  data analyst        5   West
# 15                data scientist        0   West
# 16          lead biostatistician        2   West
# 17      bioinformatics scientist        1   West
# 18                  data analyst        0   West
# 19            computer scientist        0   West
# 20                 data engineer        2   West
# 21             senior bi analyst        5   West
# 22                food scientist        5   West
# 23                 data engineer        5   West
# 24                 data engineer        5   West
# 25            computer scientist        0   West
# 26          biological scientist        5   West
# 27         business data analyst        0   West
# 28                    bi analyst        3   West
# 29           materials scientist        0   West
# 30                  data analyst        0   West
# 32                 data engineer        0   West
# 33                    bi analyst        5   West
# 34                    bi analyst        6   West
# 35       surface warfare officer        6   West
# 36                  data analyst        5   West
# 37  senior business data analyst        5   West
# 38          senior data engineer        5   West
# 39            computer scientist        0   West
# 40                    bi analyst        5   West
# 43                    bi analyst        2   West
# 44                 data engineer        0   West
# 45           data manager intern        5   West
# 46             bi analyst intern        6   West
# 47                    bi analyst        1   West
# 48                 data engineer        5   West
# 49                 data engineer        5   West
# 50        data consultant intern        5   West
# 51                    bi analyst        5   West
# 52                    bi analyst        0   West
# 53                    bi analyst        0   West
# 54          data engineer intern        6   West
# 55       surface warfare officer        0   West
# 56                    bi manager        5   West
# 57                 data engineer        0   West
# 58                 data engineer        0   West
# 59                 data engineer        5   West
# 60      senior controls engineer        5   West
# 61                    bi manager        0   West
# 62                 data engineer        0   West

# %%
# filter only three most relevant position

df_Analyst = df[df['position'].str.contains('Data Analyst',case=False, na=False) ]
df_Scientist = df[df['position'].str.contains('Data Scientist',case=False, na=False) ]
df_Engineer = df[df['position'].str.contains('Data Engineer',case=False, na=False) ]

frames = [df_Analyst, df_Scientist, df_Scientist]
glassdoor_df = pd.concat(frames)

glassdoor_df.dropna()
# Out:
#                           company  \
# 4                  Tea Collection
# 7                         TSheets
# 11              Applied Materials
# 14       St. Luke's Health System
# 18                  iVinci Health
# 27                   Agri-Service
# 30  Waterborne Environmental, Inc
# 36     United Global Technologies
# 37                         Intuit
# 0                          Amazon
# 3       Idaho National Laboratory
# 6               Micron Technology
# 8         Micron Technology, Inc.
# 9                          Vacasa
# 15                         Micron
# 0                          Amazon
# 3       Idaho National Laboratory
# 6               Micron Technology
# 8         Micron Technology, Inc.
# 9                          Vacasa
# 15                         Micron
#
#                                           description         location  \
# 4   Expectations for All Employees:Supports the or...        Boise, ID
# 7   OverviewAre you passionate about data? Do you ...        Eagle, ID
# 11  **Key Responsibilities**  Manage and facilitat...        Boise, ID
# 14  \n*Overview**\n\n\nDo you like working on thin...        Boise, ID
# 18  Summary of Position:\n\nThe Data Analyst I is ...        Boise, ID
# 27  Job DescriptionDo you have that ideal mix of s...    Blackfoot, ID
# 30  Data Analyst (Position Code VA/DA1119)\n\nData...     Leesburg, ID
# 36  The Data Analytics Report Builder will assist ...  Idaho Falls, ID
# 37  OverviewAre you passionate about data? Do you ...        Eagle, ID
# 0   Excited by using massive amounts of data to de...        Boise, ID
# 3   DescriptionJob Information\n\nJob Title: Data ...  Idaho Falls, ID
# 6   Req. ID: 139947\n\nMicron Technology’s vision ...        Boise, ID
# 8   Req. ID: 143828\n\nData Scientist\n\nMicron Te...        Boise, ID
# 9   Why Vacasa\n\nWe started with just one home an...        Boise, ID
# 15   Req. ID: 146013   Micron Technology’s vision ...        Boise, ID
# 0   Excited by using massive amounts of data to de...        Boise, ID
# 3   DescriptionJob Information\n\nJob Title: Data ...  Idaho Falls, ID
# 6   Req. ID: 139947\n\nMicron Technology’s vision ...        Boise, ID
# 8   Req. ID: 143828\n\nData Scientist\n\nMicron Te...        Boise, ID
# 9   Why Vacasa\n\nWe started with just one home an...        Boise, ID
# 15   Req. ID: 146013   Micron Technology’s vision ...        Boise, ID
#
#                         position  reviews Region
# 4                   data analyst        0   West
# 7   senior business data analyst        5   West
# 11                  data analyst        2   West
# 14                  data analyst        5   West
# 18                  data analyst        0   West
# 27         business data analyst        0   West
# 30                  data analyst        0   West
# 36                  data analyst        5   West
# 37  senior business data analyst        5   West
# 0                 data scientist        0   West
# 3                 data scientist        5   West
# 6          data scientist intern        6   West
# 8                 data scientist        4   West
# 9                 data scientist        5   West
# 15                data scientist        0   West
# 0                 data scientist        0   West
# 3                 data scientist        5   West
# 6          data scientist intern        6   West
# 8                 data scientist        4   West
# 9                 data scientist        5   West
# 15                data scientist        0   West

# %%
# new data frame with split value columns 
location_df = glassdoor_df["location"].str.split(",", n = 1, expand = True) 

# add city
glassdoor_df["City"]= location_df[0] 
  
# add state
glassdoor_df["State"]= location_df[1] 
  
# Dropping old Name columns 
glassdoor_df.drop(columns =["location"], inplace = True) 

glassdoor_df.head()
# Out:
#                      company  \
# 4             Tea Collection
# 7                    TSheets
# 11         Applied Materials
# 14  St. Luke's Health System
# 18             iVinci Health
#
#                                           description  \
# 4   Expectations for All Employees:Supports the or...
# 7   OverviewAre you passionate about data? Do you ...
# 11  **Key Responsibilities**  Manage and facilitat...
# 14  \n*Overview**\n\n\nDo you like working on thin...
# 18  Summary of Position:\n\nThe Data Analyst I is ...
#
#                         position  reviews Region   City State
# 4                   data analyst        0   West  Boise    ID
# 7   senior business data analyst        5   West  Eagle    ID
# 11                  data analyst        2   West  Boise    ID
# 14                  data analyst        5   West  Boise    ID
# 18                  data analyst        0   West  Boise    ID

# %%
glassdoor_df.to_csv(f'../../Load/Resources/Glassdoor/{statename}_glassdoor.csv',sep='|',index=False)
