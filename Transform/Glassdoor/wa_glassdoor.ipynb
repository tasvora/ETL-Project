# %%
import pandas as pd

# %%
df = pd.read_excel("../Resources/Glassdoor/wa_glassdoor.xlsx")

# %%
df.head()
# Out:
#          company                                        description  \
# 0       Outreach  About The TeamData is at the core of Outreach'...
# 1  Knowesis Inc.  Job Description:Knowesis is looking for person...
# 2          ADURO  SUMMARY:\n\n\nResponsible for managing the col...
# 3      PicMonkey  Weve got our eyes peeled for a Data Analyst wh...
# 4       Ring LLC  Ring is looking for a Data Scientist to join a...
#
#          location        position  reviews
# 0     Seattle, WA  data scientist        5
# 1  Fort Lewis, WA  data scientist        0
# 2     Redmond, WA    data analyst        5
# 3     Seattle, WA    data analyst        0
# 4     Seattle, WA  data scientist        0

# %%
# filter only three most relevant position

df_Analyst = df[df['position'].str.contains('Data Analyst',case=False) ]
df_Scientist = df[df['position'].str.contains('Data Scientist',case=False) ]
df_Engineer = df[df['position'].str.contains('Data Engineer',case=False) ]

frames = [df_Analyst, df_Scientist, df_Scientist]
glassdoor_df = pd.concat(frames)

glassdoor_df.head(50)
# Out:
#                            company  \
# 2                            ADURO
# 3                        PicMonkey
# 7                         ProKarma
# 17              Pivotal Consulting
# 22              Inspiration Global
# 45                 Bridge Partners
# 55              Fisher Investments
# 93                        AdColony
# 96                        LiveRamp
# 103                 Veear Projects
# 119   Transaction Network Services
# 129                         Ascent
# 132                  LanceSoft Inc
# 133                    AiTech Corp
# 152        Overlake Medical Center
# 168           Course5 Intelligence
# 174                        Experis
# 177                 Seen by Indeed
# 183  Blueocean Market Intelligence
# 193          Rainier Fruit Company
# 198                Mastech Digital
# 253          Rainier Fruit Company
# 263                Mastech Digital
# 279                        Pactera
# 297    Pactera Technology NA, Inc.
# 301                G2 Web Services
# 311       Adaptive Biotechnologies
# 314                         Kforce
# 317             Silicontek Systems
# 339                         Verisk
# 342                         Verisk
# 373           CHILDRENS HOSPITAL &
# 392                     Net2Source
# 421                   Salient CRGT
# 465                 Big Fish Games
# 486                           DESC
# 531                     Net2Source
# 536                        Groupon
# 539     APN Software Services Inc.
# 551                           PATH
# 561                PetroCard, Inc.
# 567                          Ursus
# 589                   Salient CRGT
# 654                         eXcell
# 664                 Big Fish Games
# 681           Amazon Corporate LLC
# 700                           DESC
# 709    Virtuosity Consulting Group
# 770        ExtraHop Networks, Inc.
# 801                 Big Fish Games
#
#                                            description       location  \
# 2    SUMMARY:\n\n\nResponsible for managing the col...    Redmond, WA
# 3    Weve got our eyes peeled for a Data Analyst wh...    Seattle, WA
# 7    Description\n\nProKarma currently has exciting...    Seattle, WA
# 17   Are you a Data Analyst/Jr. Data Scientist with...    Redmond, WA
# 22   We are looking for a passionate certified Data...    Seattle, WA
# 45   We are seeking a Data Analyst to join our fast...   Bellevue, WA
# 55   OverviewFisher Investments Workforce Planning ...      Camas, WA
# 93   \nWe are looking for a Data Analyst who can de...   Bellevue, WA
# 96   ABOUT LIVERAMP\n\nLiveRamp is the trusted plat...    Seattle, WA
# 103  Title: Data Analyst/Scientist\n\nLocation: Sea...    Seattle, WA
# 119  Data Analyst\n\nPosition Description\n\nThe Sp...    Seattle, WA
# 129  Translational Development Coordinator\n\nContr...    Seattle, WA
# 132   Job Description:\n\nWe are looking for a pass...    Seattle, WA
# 133  Title: Data Analyst/Scientist\n\nLocation: Sea...    Seattle, WA
# 152  The Senior Population Health Analyst is a key ...   Bellevue, WA
# 168  Requirement in short - (SQL based Transactiona...    Seattle, WA
# 174  Job DescriptionWe are seeking a Data Analyst f...    Seattle, WA
# 177  Seen by Indeed is a free service that connects...    Seattle, WA
# 183  Requirement in short - (SQL based Transactiona...    Seattle, WA
# 193  Job DescriptionRainier Fruit Company of Selah,...      Selah, WA
# 198  Mastech Digital provides digital and mainstrea...     Renton, WA
# 253  Job DescriptionRainier Fruit Company of Selah,...      Selah, WA
# 263  Mastech Digital provides digital and mainstrea...     Renton, WA
# 279  I’m Susheel from Pactera. We do have a very ur...    Redmond, WA
# 297  Role : Data Analyst\n\nLocation : Redmond, WA\...    Redmond, WA
# 301  Company DescriptionG2 has been the world leade...   Bellevue, WA
# 311  Every immune system has a story to tell the ke...    Seattle, WA
# 314  RESPONSIBILITIES:Kforce has a client in search...    Seattle, WA
# 317  Job Description:\n\nResponsibilities:\n\nProvi...    Seattle, WA
# 339  Company DescriptionG2 has been the world leade...   Bellevue, WA
# 342  Company DescriptionG2 has been the world leade...   Bellevue, WA
# 373  Data Analyst Sr\n\nJob ID2019-31450Area of Int...    Seattle, WA
# 392  Net2Source is a Global Workforce Solutions Com...    Seattle, WA
# 421  Job DescriptionApplies logic, decision science...  Vancouver, WA
# 465  Job Posting TitleSenior Data AnalystSummaryLif...    Seattle, WA
# 486  Job Title: Health Integration Data Analyst\n\n...    Seattle, WA
# 531  Net2Source is a Global Workforce Solutions Com...    Seattle, WA
# 536  Groupon’s mission is to become the daily habit...    Seattle, WA
# 539  \nDescription:   Job title:  Data Analyst   Re...    Bothell, WA
# 551  Tracking Code\n\n9661\n\nJob Description\n\nPl...    Seattle, WA
# 561  PetroCard is More than just fuel. We are the l...       Kent, WA
# 567  Job Title: Data Analyst IV\n\nLocation: Seattl...    Seattle, WA
# 589  Job DescriptionApplies logic, decision science...  Vancouver, WA
# 654  Did you know that Gartner positioned eXcell as...    Redmond, WA
# 664  Job Posting TitleSenior Data AnalystSummaryLif...    Seattle, WA
# 681  Are you excited and passionate about deliverin...    Seattle, WA
# 700  Job Title: Health Integration Data Analyst\n\n...    Seattle, WA
# 709  Sorry, NO visa sponsorship availiable\n\n Only...    Redmond, WA
# 770  As a Data Analyst within the ExtraHop Customer...    Seattle, WA
# 801  Job Posting TitleSenior Data AnalystSummaryLif...    Seattle, WA
#
#                 position  reviews
# 2           data analyst        5
# 3           data analyst        0
# 7           data analyst        5
# 17          data analyst        0
# 22          data analyst        0
# 45          data analyst        2
# 55          data analyst        5
# 93          data analyst        1
# 96          data analyst        0
# 103         data analyst        0
# 119         data analyst        1
# 129         data analyst        0
# 132         data analyst        2
# 133         data analyst        0
# 152  senior data analyst        5
# 168         data analyst        0
# 174         data analyst        5
# 177         data analyst        0
# 183         data analyst        2
# 193         data analyst        0
# 198         data analyst        0
# 253         data analyst        0
# 263         data analyst        0
# 279         data analyst        5
# 297         data analyst        0
# 301         data analyst        4
# 311         data analyst        5
# 314         data analyst        5
# 317         data analyst        0
# 339         data analyst        0
# 342         data analyst        0
# 373  senior data analyst        0
# 392         data analyst        0
# 421         data analyst        0
# 465  senior data analyst        5
# 486         data analyst        5
# 531         data analyst        0
# 536  senior data analyst        5
# 539         data analyst        0
# 551         data analyst        5
# 561  senior data analyst        0
# 567         data analyst        0
# 589         data analyst        0
# 654         data analyst        5
# 664  senior data analyst        5
# 681         data analyst        2
# 700         data analyst        5
# 709         data analyst        2
# 770  senior data analyst        5
# 801  senior data analyst        5

# %%
# new data frame with split value columns 
location_df = glassdoor_df["location"].str.split(",", n = 1, expand = True) 

# add city
glassdoor_df["City"]= location_df[0] 
  
# add state
glassdoor_df["State"]= location_df[1] 
  
# Dropping old Name columns 
glassdoor_df.drop(columns =["location"], inplace = True) 

glassdoor_df.head()
# Out:
#                company                                        description  \
# 2                ADURO  SUMMARY:\n\n\nResponsible for managing the col...
# 3            PicMonkey  Weve got our eyes peeled for a Data Analyst wh...
# 7             ProKarma  Description\n\nProKarma currently has exciting...
# 17  Pivotal Consulting  Are you a Data Analyst/Jr. Data Scientist with...
# 22  Inspiration Global  We are looking for a passionate certified Data...
#
#         position  reviews     City State
# 2   data analyst        5  Redmond    WA
# 3   data analyst        0  Seattle    WA
# 7   data analyst        5  Seattle    WA
# 17  data analyst        0  Redmond    WA
# 22  data analyst        0  Seattle    WA

# %%
glassdoor_df.to_csv('../../Load/Resources/Glassdoor/wa_glassdoor.csv',sep='|',index=False)
