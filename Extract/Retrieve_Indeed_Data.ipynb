# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
browser = webdriver.Chrome('windows/chromedriver')
#job_type = ["Data+Scientist"]#,"Data+Engineer","Data+Analyst"]
#job_state = ["Washington"]#,"New+York","Massachusetts","Ohio","California"]
#https://www.indeed.com/jobs?q=Data+Analyst+python+pandas&l=Washington
job_type = "Data+Analyst"
job_state = "Ohio"
skills = "+python+pandas"
job_criteria = job_type
url = "https://www.indeed.com/jobs?q=" + job_criteria + "&l="+job_state
print(url)
browser.get(url)
time.sleep(1)
# Out:
# https://www.indeed.com/jobs?q=Data+Analyst&l=Ohio

# %%
#Creating a List here
job_title = []
x = 0
scrapping_bool = True
while scrapping_bool:
    x +=1
    # HTML object
    html = browser.page_source
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    # Retrieve all elements that job opening information
    job_listing = soup.find_all('div', class_='jobsearch-SerpJobCard')
    #print(f"this is the no of job listing on webpage {x}")
   # print(f"this is the no of job listing obtained {len(job_title)}")

    for listing in job_listing:
        
        title_detail = listing.find('div',class_='title')
        title = title_detail.a['title']
        
        company_detail = listing.find('div',class_='sjcl')
        company_name = company_detail.span.text.strip()
        
        handle_loc = listing.find('div',class_='recJobLoc')
        location = handle_loc['data-rc-loc'].strip()
        job_summary = listing.find('div',class_='summary').text.strip()
        #handle_reviews = listing.find('span',class_='slNoUnderline')
        #handle_ratings = listing.find('span',class_='ratings')
        #if handle_reviews is None:
            #continue
        #else:
            #reviews = handle_reviews.text.strip()
            #ratings = handle_ratings['aria-label']
            
        #Creating a dictionary here
        #print(company_name)
        dict_jobopening = {"job_title": title,"company_name": company_name,"location":location,
                          "job_summary": job_summary}#,"reviews": reviews,"ratings": ratings}
        job_title.append(dict_jobopening)
        
        time.sleep(1)
       
    try:
        #alert = browser.switch_to_alert()
        #alert.dismiss()

        browser.find_element_by_partial_link_text('No, thanks').click() 
        time.sleep(1)

    except:
        print("No Pop-Up Found.")

    try:
        time.sleep(1)
        print(f"Lenght of list is {len(job_title)}")
        time.sleep(1)
        print(company_name)
        #browser.find_element_by_xpath("/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[2]/div[31]/a[10]/span/span").click()
        nextElem = browser.find_element_by_partial_link_text('Next')
        print(nextElem.text)
        if(nextElem.text == "Next »"):
            nextElem.click()
        
        print(f"Clicking Next {x}")
        time.sleep(1)
    except NoSuchElementException:

        print("Scraping Complete")
        scrapping_bool = False
        break
            
    
browser.close()
# Out:
# No Pop-Up Found.
# Lenght of list is 16
# NOF Metal Coatings Group North America
# Next »
# Clicking Next 1
# Lenght of list is 33
# Insight Global
# Next »
# Clicking Next 2
# No Pop-Up Found.
# Lenght of list is 52
# Embrace Pet Insurance
# Next »
# Clicking Next 3
# No Pop-Up Found.
# Lenght of list is 68
# Eagle Family Foods Group LLC
# Next »
# Clicking Next 4
# No Pop-Up Found.
# Lenght of list is 83
# American Chemical Society
# Next »
# Clicking Next 5
# No Pop-Up Found.
# Lenght of list is 98
# Fast Switch
# Next »
# Clicking Next 6
# No Pop-Up Found.
# Lenght of list is 114
# Updox
# Next »
# Clicking Next 7
# No Pop-Up Found.
# Lenght of list is 130
# Cognosante, LLC
# Next »
# Clicking Next 8
# No Pop-Up Found.
# Lenght of list is 145
# Interim HealthCare
# Next »
# Clicking Next 9
# No Pop-Up Found.
# Lenght of list is 160
# Verizon
# Next »
# Clicking Next 10
# No Pop-Up Found.
# Lenght of list is 175
# Step2
# Next »
# Clicking Next 11
# No Pop-Up Found.
# Lenght of list is 190
# Endevis
# Next »
# Clicking Next 12
# No Pop-Up Found.
# Lenght of list is 203
# Centric Consulting
# Next »
# Clicking Next 13
# No Pop-Up Found.
# Lenght of list is 215
# CAS
# Next »
# Clicking Next 14
# No Pop-Up Found.
# Lenght of list is 226
# QTC Management, Inc.
# Next »
# Clicking Next 15
# No Pop-Up Found.
# Lenght of list is 238
# Asurint
# Next »
# Clicking Next 16
# No Pop-Up Found.
# Lenght of list is 250
# Intersect ENT
# Next »
# Clicking Next 17
# No Pop-Up Found.
# Lenght of list is 263
# TACG, LLC
# Next »
# Clicking Next 18
# No Pop-Up Found.
# Lenght of list is 275
# Kelly Services
# Next »
# Clicking Next 19
# No Pop-Up Found.
# Lenght of list is 287
# Park Place Technologies
# Next »
# Clicking Next 20
# No Pop-Up Found.
# Lenght of list is 299
# Selman & Company LLC
# Next »
# Clicking Next 21
# No Pop-Up Found.
# Lenght of list is 311
# Progressive
# Next »
# Clicking Next 22
# No Pop-Up Found.
# Lenght of list is 323
# Worldpay
# Next »
# Clicking Next 23
# No Pop-Up Found.
# Lenght of list is 335
# Interesse International Inc
# Next »
# Clicking Next 24
# No Pop-Up Found.
# Lenght of list is 346
# Post Consumer Brands
# Next »
# Clicking Next 25
# No Pop-Up Found.
# Lenght of list is 357
# Nationwide Children's Hospital
# Next »
# Clicking Next 26
# No Pop-Up Found.
# Lenght of list is 368
# Park National Bank
# Next »
# Clicking Next 27
# No Pop-Up Found.
# Lenght of list is 378
# Sherwin-Williams
# Next »
# Clicking Next 28
# No Pop-Up Found.
# Lenght of list is 388
# National Automotive Experts
# Next »
# Clicking Next 29
# No Pop-Up Found.
# Lenght of list is 398
# State of Ohio Jobs
# Next »
# Clicking Next 30
# No Pop-Up Found.
# Lenght of list is 408
# Nationwide Children's Hospital
# Next »
# Clicking Next 31
# No Pop-Up Found.
# Lenght of list is 418
# Huntington Bank
# Next »
# Clicking Next 32
# No Pop-Up Found.
# Lenght of list is 428
# Fifth Third Bank
# Next »
# Clicking Next 33
# No Pop-Up Found.
# Lenght of list is 438
# Materion
# Next »
# Clicking Next 34
# No Pop-Up Found.
# Lenght of list is 448
# Medpace
# Next »
# Clicking Next 35
# No Pop-Up Found.
# Lenght of list is 458
# JPMorgan Chase
# Next »
# Clicking Next 36
# No Pop-Up Found.
# Lenght of list is 468
# American Electric Power
# Next »
# Clicking Next 37
# No Pop-Up Found.
# Lenght of list is 478
# Passion Growers
# Next »
# Clicking Next 38
# No Pop-Up Found.
# Lenght of list is 488
# Fifth Third Bank
# Next »
# Clicking Next 39
# No Pop-Up Found.
# Lenght of list is 498
# coty
# Next »
# Clicking Next 40
# No Pop-Up Found.
# Lenght of list is 508
# UC Health
# Next »
# Clicking Next 41
# No Pop-Up Found.
# Lenght of list is 518
# Frontend Arts
# Next »
# Clicking Next 42
# No Pop-Up Found.
# Lenght of list is 528
# Covia Corp
# Next »
# Clicking Next 43
# No Pop-Up Found.
# Lenght of list is 538
# Eaton
# Next »
# Clicking Next 44
# No Pop-Up Found.
# Lenght of list is 548
# The Hillman Group
# Next »
# Clicking Next 45
# No Pop-Up Found.
# Lenght of list is 558
# McGraw-Hill
# Next »
# Clicking Next 46
# No Pop-Up Found.
# Lenght of list is 568
# Moen
# Next »
# Clicking Next 47
# No Pop-Up Found.
# Lenght of list is 578
# State Industrial Products
# Next »
# Clicking Next 48
# No Pop-Up Found.
# Lenght of list is 588
# Fifth Third Bank
# Next »
# Clicking Next 49
# No Pop-Up Found.
# Lenght of list is 598
# ComResource
# Next »
# Clicking Next 50
# No Pop-Up Found.
# Lenght of list is 608
# Traction on Demand
# Next »
# Clicking Next 51
# No Pop-Up Found.
# Lenght of list is 618
# Fifth Third Bank
# Next »
# Clicking Next 52
# No Pop-Up Found.
# Lenght of list is 628
# American Chemical Society
# Next »
# Clicking Next 53
# No Pop-Up Found.
# Lenght of list is 638
# Fifth Third Bank
# Next »
# Clicking Next 54
# No Pop-Up Found.
# Lenght of list is 644
# Appirio
# Next »
# Clicking Next 55
# No Pop-Up Found.
# Lenght of list is 659
# NOF Metal Coatings Group North America
# Next »
# Clicking Next 56
# No Pop-Up Found.
# Lenght of list is 675
# Nestle USA
# Scraping Complete

# %%
job_title_df = pd.DataFrame(job_title)
job_title_df.head()
# Out:
#                    company_name  \
# 0   Universal Screen Arts, Inc.
# 1           Race Winning Brands
# 2  LeafFilter Gutter Protection
# 3                   T-CETRA LLC
# 4               Harley-Davidson
#
#                                          job_summary  \
# 0  Attentive to detail and high level of accuracy...
# 1  Race Winning Brands is a leader in developing ...
# 2  This is a highly collaborative role where you ...
# 3  We're constantly developing new and creative w...
# 4  Typically requires a minimum of 3 years of rel...
#
#                                     job_title         location
# 0  Marketing Manager - Print & Data Analytics       Hudson, OH
# 1                                Data Analyst       Mentor, OH
# 2     Human Resources Data Analyst - Contract       Hudson, OH
# 3                         Data Analyst Tier I       Dublin, OH
# 4                                Data Analyst  Valley View, OH

# %%
# new data frame with split value columns 
new = job_title_df["location"].str.split(",", n = 1, expand = True) 
#print(new)  
# making separate first name column from new data frame 
job_title_df["City"]= new[0] 
  
# making separate last name column from new data frame 
job_title_df["State"]= new[1] 
  
# Dropping old Name columns 
job_title_df.drop(columns =["location"], inplace = True)

# %%
len(job_title_df)
# Out:
# 675

# %%
outFileName = job_state+"_output"+job_type+".xlsx"
print(outFileName)
job_title_df.to_excel("/output/outFileName)
# Out:
# Ohio_outputData+Analyst.xlsx
